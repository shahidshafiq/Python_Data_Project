# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_salary = df[pd.notna(df["salary_year_avg"])]

# %%
df_salary
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
df_salary["salary_year_inflated"] = df_salary["salary_year_avg"].apply(lambda salary: salary *2)
# Out:
# /var/folders/v2/k0pjj8ms2nd5y__x0cxrdmy80000gn/T/ipykernel_27343/4129736729.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary["salary_year_inflated"] = df_salary["salary_year_avg"].apply(lambda salary: salary *2)

# %%
df_salary[["salary_year_avg", "salary_year_inflated"]].head()
# Out:
#      salary_year_avg  salary_year_inflated
# 28          109500.0              219000.0
# 77          140000.0              280000.0
# 92          120000.0              240000.0
# 100         228222.0              456444.0
# 109          89000.0              178000.0

# %%
def calculated_salary(salary):
    return salary *1.03
df_salary["salary_year_inflated"] = df_salary["salary_year_avg"].apply(calculated_salary)
# Out:
# /var/folders/v2/k0pjj8ms2nd5y__x0cxrdmy80000gn/T/ipykernel_27343/1671243943.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary["salary_year_inflated"] = df_salary["salary_year_avg"].apply(calculated_salary)

# %%
df_salary[["salary_year_avg", "salary_year_inflated"]].head()
# Out:
#      salary_year_avg  salary_year_inflated
# 28          109500.0             112785.00
# 77          140000.0             144200.00
# 92          120000.0             123600.00
# 100         228222.0             235068.66
# 109          89000.0              91670.00

# %%
(df["job_skills"][1])
# Out:
# "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"

# %%
import ast
ast.literal_eval(df["job_skills"][1])
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
def clean_list(skills_list):
    if pd.notna(skills_list):
        return ast.literal_eval(skills_list)

# %%
df["job_skills"] = df["job_skills"].apply(clean_list)

# %%
type(df["job_skills"][1])
# Out:
# list

# %%
df["job_skills"] = df["job_skills"].apply(lambda skills_list: ast.literal_eval(skills_list) if pd.notna(skills_list) else (skills_list))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df["job_skills"] = df["job_skills"].apply(lambda skills_list: ast.literal_eval(skills_list) if pd.notna(skills_list) else (skills_list))
#
# File /Users/Shared/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
# ...

# %%
df_salary
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
def projected_salary(row):
    if "Senior" in row["job_title_short"]:
        return 1.05 * row["salary_year_avg"]
    else:
        return 1.03 * row["slary_year_avg"]
df["salary_year_inflated_all"] = df_salary.apply(calculated_salary, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Users/Shared/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File /Users/Shared/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /Users/Shared/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# ...
