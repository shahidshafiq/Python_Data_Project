# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
import ast
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# Data Only for Data Analsyt

# %%
df_DA = df[df["job_title_short"] == "Data Analyst"].copy()

# %%
df_DA
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_DA["job_posted_month_no"] = df_DA["job_posted_date"].dt.month

# %%
df_DA_exploded = df_DA.explode("job_skills")

# %%
df_DA_pivot = df_DA_exploded.pivot_table(index = "job_posted_month_no", columns= "job_skills" , aggfunc="size" , fill_value=0)

# %%
df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
df_DA_pivot.sum()
# Out:
# job_skills
# airflow       2002.0
# airtable        88.0
# alteryx       4570.0
# angular        376.0
# angular.js       2.0
#                ...
# wrike           39.0
# wsl             16.0
# xamarin          2.0
# yarn            76.0
# zoom           465.0
# Length: 235, dtype: float64

# %%
df_DA_pivot.loc["Total"] = df_DA_pivot.sum()

# %%
df_DA_pivot["python"]
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
df_DA_pivot.loc["Total"].sort_values(ascending=False)
# Out:
# job_skills
# sql          184856
# excel        133720
# python       114380
# tableau       92910
# power bi      78760
#               ...
# esquisse          2
# suse              2
# capacitor         2
# chainer           2
# msaccess          2
# Name: Total, Length: 235, dtype: int64

# %%
df_DA_pivot.loc["Total"].sort_values(ascending=False).index
# Out:
# Index(['sql', 'excel', 'python', 'tableau', 'power bi', 'r', 'sas',
#        'powerpoint', 'word', 'sap',
#        ...
#        'angular.js', 'xamarin', 'gtx', 'nuxt.js', 'ovh', 'esquisse', 'suse',
#        'capacitor', 'chainer', 'msaccess'],
#       dtype='object', name='job_skills', length=235)

# %%
df_DA_pivot_done = df_DA_pivot[df_DA_pivot.loc["Total"].sort_values(ascending=False).index]

# %%
df_DA_ready = df_DA_pivot_done.drop("Total")

# %%
df_DA_ready.iloc[:, :5].plot(kind="line")
# Out:
# <Axes: xlabel='job_posted_month_no'>
